# %% [markdown]
# # 🎤 Test STT - Groq Whisper API
#
# Testez la transcription audio avec Groq.

# %%
import sys
sys.path.append('/app')
from src.voice.stt import transcribe_audio
from pathlib import Path
import asyncio

# %%
# Créer un audio de test
import edge_tts

text = "Bonjour, test de transcription"
audio_path = Path('/tmp/test.mp3')

async def create():
    tts = edge_tts.Communicate(text, 'fr-FR-DeniseNeural')
    await tts.save(str(audio_path))

await create()
print(f"Audio créé: {audio_path}")
# Out:
# Audio créé: /tmp/test.mp3

# %%
# Transcrire
import time

start = time.time()
transcription = await transcribe_audio(audio_path, 'fr')
duration = time.time() - start

print(f"Original: {text}")
print(f"Transcription: {transcription}")
print(f"Temps: {duration:.2f}s")
# Out:
# 2026-01-06 18:24:16.398 | INFO     | src.voice.stt:__init__:121 - Initialized Groq STT
# 2026-01-06 18:24:17.046 | INFO     | src.voice.stt:transcribe:137 - Transcribing with Groq: /tmp/test.mp3
# 2026-01-06 18:24:17.391 | INFO     | src.voice.stt:transcribe:155 - Transcription: Bonjour, test de transcription.
# Original: Bonjour, test de transcription
# Transcription: Bonjour, test de transcription.
# Temps: 1.00s
