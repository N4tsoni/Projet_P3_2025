# %% [markdown]
# # 🤖 Test Agent Conversationnel
#
# Testez l'agent avec OpenRouter/Claude.

# %%
import sys
sys.path.append('/app')
from src.agents.jarvis_agent import get_agent
import asyncio

# %%
# Conversation simple
agent = get_agent()

questions = [
    "Bonjour, qui es-tu?",
    "Quelle est la capitale de la France?",
    "Mémorise que j'aime le café"
]

for q in questions:
    response = await agent.chat(q)
    print(f"Q: {q}")
    print(f"R: {response}\n")
